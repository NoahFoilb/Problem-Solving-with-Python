# %% [markdown]
# ## CSC1611 Problem Solving Using Python
# Homework 4 due on 11/3 at midnight
#
# <i>Your full name goes here</i>

# %% [markdown]
# Rules:
# 1. <b>Any solution having a Python error will get zero points.</b> If you cannot solve a problem completely, it may be better to submit a clean partial solution having no errors rather than to submit a solution having errors.
# 2. Ensure that your solution is executed, the output is shown, and the cell execution sequence is consecutive.
# 3. Do not use the input function, list, or any other Python features that have not been fully covered according to the course schedule. Furthermore, do not import any modules for this assignment. If not sure, ask me for clarification.
# 4. Submit the final version of this Notebook file to Blackboard. Ensure that the file extension is .ipynb and it can be loaded into Jupyter Notebook. .json and .html files are not accepted.

# %% [markdown]
# ### Problem 1

# %% [markdown]
# (2 points) A person is eligible to be a US Senator who is at least 30 years old and has been a US citizen for at least 9 years. A person is eligible to be a US Representative who is at least 25 years old and has been a US citizen for at least 7 years.
#
# Write a non-interactive function, named congress, which takes age and years of citizenship as formal parameters and returns, but not prints, one of the following three statements that is accurate:
#
# - "You are eligible for both the House and Senate."
# - "You are eligible only for the House."
# - "You are ineligible for Congress."
#
# These three cases are mutually exclusive.
#
# Demonstrate the workings of your function using the following code segment:
# <pre>
# tests = [(30,9), (30,7), (30,6), (29,9), (29,7), (29,6), (25,9), (25,7), (25,6), (24,9), (24,7), (24,6)]
# for age,citizenship in tests:
#     verdict = congress(age, citizenship)
#     print(f"Age {age}, citizenship {citizenship}: {verdict}")
# <pre>

# %%
# Your solution goes here. Do not add additional cells.
# Freely add additional variables, expressions, statements, and functions.
# All the defined identifiers must be used in solving the given problem.
# In other words, do not leave any unused variables.

# %% [markdown]
# ### Problem 2

# %% [markdown]
# (3 points) Write a non-interactive function, called pyramid, which takes an integer n and a string s, draws a perfectly symmetrical n-layer pyramid of s, and also returns the total number of s drawn in the pyramid. Review the attached image which is generated by calling the function 3 times with n being 3, 6, and 15, and s being '*'. A space is inserted between two adjacent asterisks. The numbers were printed by the caller of the function.
#
# The pyramid has always one symbol on layer 1, 3 symbols on layer 2, and so forth with n symbols at the bottom layer. The trick for giving an illusion of a symmetric pyramid is to draw some number of spaces before the first symbol on a layer. Your task is to formulate the number-sequence pattern of spaces and symbols to be drawn on an arbitrary layer.
#
# Remember that you write the pyramid function once in your solution which works correctly for any value for n and s. The function must be implemented using nested loop(s), either for or while. A solution using the string repetition or concatenation operator will get zero points.
#
# Your solution must work with any natural numbers and symbols. Demonstrate the workings of your function using the following code segment:
# <pre>
# for i in [3, 6, 15]:
#     num_symbols = pyramid(i, '*')
#     print(f"Height of pyramid={i}")
#     print(f"Number of symbols used={num_symbols}")
#     print()
# </pre>

# %%
# Your solution goes here. Do not add additional cells.
# Freely add additional variables, expressions, statements, and functions.
# All the defined identifiers must be used in solving the given problem.
# In other words, do not leave any unused variables.

# %% [markdown]
# ### Problem 3

# %% [markdown]
# (3 points) Write a non-interactive function, called echo, which takes a string s and returns True if the string reads the same backward as forward when punctuation and spaces are disregarded, e.g., "civic", "deified!", "Eve", "madam", "Madam I'm Adam", and "nurses run". Otherwise it returns False.
#
# Punctuation symbols are:
# <pre>
# !"#$%&\'()*+,-./:;<=>?@[\\]^_`{|}~
# </pre>
#
# Your function must implement the removal of punctuation and spaces using a for or while loop. Also, a for or while must be used to compare two characters at a time. Do not use any string methods that have not been introduced in this class.
#
# Your solution must skip any punctuation. Demonstrate the workings of your function using the following code segment:
# <pre>
# tests = ["civic", "deified!", "Eve", "madam", "Madam I'm Adam", "nurses run", "banana", "abracadabra"]
#
# for t in tests:
#     p = echo(t)
#     print(f'{t:>15}: {p}')
# </pre>

# %%
# Your solution goes here. Do not add additional cells.
# Freely add additional variables, expressions, statements, and functions.
# All the defined identifiers must be used in solving the given problem.
# In other words, do not leave any unused variables.
